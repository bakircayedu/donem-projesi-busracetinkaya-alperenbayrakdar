-- %% [markdown]
-- # [Gamerary]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [Gamerary]    Script Date: 05/01/2022 22:36:30 ******/
CREATE DATABASE [Gamerary]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'Gamerary', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.MSSQLSERVER\MSSQL\DATA\Gamerary.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'Gamerary_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.MSSQLSERVER\MSSQL\DATA\Gamerary_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT
GO
ALTER DATABASE [Gamerary] SET COMPATIBILITY_LEVEL = 150
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [Gamerary].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [Gamerary] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [Gamerary] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [Gamerary] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [Gamerary] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [Gamerary] SET ARITHABORT OFF 
GO
ALTER DATABASE [Gamerary] SET AUTO_CLOSE ON 
GO
ALTER DATABASE [Gamerary] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [Gamerary] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [Gamerary] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [Gamerary] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [Gamerary] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [Gamerary] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [Gamerary] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [Gamerary] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [Gamerary] SET  ENABLE_BROKER 
GO
ALTER DATABASE [Gamerary] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [Gamerary] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [Gamerary] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [Gamerary] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [Gamerary] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [Gamerary] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [Gamerary] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [Gamerary] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [Gamerary] SET  MULTI_USER 
GO
ALTER DATABASE [Gamerary] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [Gamerary] SET DB_CHAINING OFF 
GO
ALTER DATABASE [Gamerary] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [Gamerary] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [Gamerary] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [Gamerary] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [Gamerary] SET QUERY_STORE = OFF
GO

-- %% [markdown]
-- # [dbo].[Account]

-- %%
USE [Gamerary]
GO

-- %%
/****** Object:  Table [dbo].[Account]    Script Date: 05/01/2022 22:36:30 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Account](
	[accountID] [int] IDENTITY(1,1) NOT NULL,
	[firstName] [nvarchar](50) NOT NULL,
	[lastName] [nvarchar](50) NOT NULL,
	[birthdate] [nvarchar](10) NOT NULL,
	[userAddress] [nvarchar](200) NULL,
	[phoneNumber] [nvarchar](10) NOT NULL,
	[eMail] [nvarchar](50) NOT NULL,
	[passwrd] [nvarchar](50) NOT NULL,
	[uAccountID] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[accountID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Game]

-- %%
/****** Object:  Table [dbo].[Game]    Script Date: 05/01/2022 22:36:30 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Game](
	[gameID] [int] IDENTITY(1,1) NOT NULL,
	[platformID] [int] NULL,
	[genreID] [int] NULL,
	[gameName] [nvarchar](50) NOT NULL,
	[publisherName] [nvarchar](50) NOT NULL,
	[developerName] [nvarchar](50) NOT NULL,
	[releaseDate] [nvarchar](10) NOT NULL,
	[price] [money] NOT NULL,
	[rating] [float] NULL,
	[content] [nvarchar](500) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[gameID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[GameList]

-- %%
/****** Object:  Table [dbo].[GameList]    Script Date: 05/01/2022 22:36:30 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[GameList](
	[gameListID] [int] IDENTITY(1,1) NOT NULL,
	[uAccountID] [int] NULL,
	[gameID] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[gameListID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[GamePlatform]

-- %%
/****** Object:  Table [dbo].[GamePlatform]    Script Date: 05/01/2022 22:36:30 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[GamePlatform](
	[platformID] [int] IDENTITY(1,1) NOT NULL,
	[platformName] [nvarchar](30) NULL,
PRIMARY KEY CLUSTERED 
(
	[platformID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Genre]

-- %%
/****** Object:  Table [dbo].[Genre]    Script Date: 05/01/2022 22:36:30 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Genre](
	[genreID] [int] IDENTITY(1,1) NOT NULL,
	[genre] [nvarchar](30) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[genreID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[UserAccount]

-- %%
/****** Object:  Table [dbo].[UserAccount]    Script Date: 05/01/2022 22:36:30 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[UserAccount](
	[uAccountID] [int] IDENTITY(1,1) NOT NULL,
	[uFirstName] [nvarchar](50) NOT NULL,
	[uLastName] [nvarchar](50) NOT NULL,
	[uBirthdate] [nvarchar](10) NOT NULL,
	[uUserAddress] [nvarchar](200) NULL,
	[uPhoneNumber] [nvarchar](10) NOT NULL,
	[uEMail] [nvarchar](50) NOT NULL,
	[uPasswrd] [nvarchar](50) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[uAccountID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK_Account_UserAccount]

-- %%
ALTER TABLE [dbo].[Account]  WITH CHECK ADD  CONSTRAINT [FK_Account_UserAccount] FOREIGN KEY([uAccountID])
REFERENCES [dbo].[UserAccount] ([uAccountID])
GO
ALTER TABLE [dbo].[Account] CHECK CONSTRAINT [FK_Account_UserAccount]
GO

-- %% [markdown]
-- # [FK_Game_GamePlatform]

-- %%
ALTER TABLE [dbo].[Game]  WITH CHECK ADD  CONSTRAINT [FK_Game_GamePlatform] FOREIGN KEY([platformID])
REFERENCES [dbo].[GamePlatform] ([platformID])
GO
ALTER TABLE [dbo].[Game] CHECK CONSTRAINT [FK_Game_GamePlatform]
GO

-- %% [markdown]
-- # [FK_Game_Genre]

-- %%
ALTER TABLE [dbo].[Game]  WITH CHECK ADD  CONSTRAINT [FK_Game_Genre] FOREIGN KEY([genreID])
REFERENCES [dbo].[Genre] ([genreID])
GO
ALTER TABLE [dbo].[Game] CHECK CONSTRAINT [FK_Game_Genre]
GO

-- %% [markdown]
-- # [FK_GameList_Game]

-- %%
ALTER TABLE [dbo].[GameList]  WITH CHECK ADD  CONSTRAINT [FK_GameList_Game] FOREIGN KEY([gameID])
REFERENCES [dbo].[Game] ([gameID])
GO
ALTER TABLE [dbo].[GameList] CHECK CONSTRAINT [FK_GameList_Game]
GO

-- %% [markdown]
-- # [FK_GameList_UserAccount]

-- %%
ALTER TABLE [dbo].[GameList]  WITH CHECK ADD  CONSTRAINT [FK_GameList_UserAccount] FOREIGN KEY([uAccountID])
REFERENCES [dbo].[UserAccount] ([uAccountID])
GO
ALTER TABLE [dbo].[GameList] CHECK CONSTRAINT [FK_GameList_UserAccount]
GO

-- %% [markdown]
-- # [dbo].[sp_EnPahalıOyun]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_EnPahalıOyun]    Script Date: 05/01/2022 22:36:30 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


 CREATE PROCEDURE [dbo].[sp_EnPahalıOyun]
AS 
BEGIN 
SELECT TOP 1* FROM Game 
ORDER BY price DESC 
END
GO

-- %% [markdown]
-- # [dbo].[sp_EnYeniOyunPc]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_EnYeniOyunPc]    Script Date: 05/01/2022 22:36:30 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


CREATE PROCEDURE [dbo].[sp_EnYeniOyunPc]
AS 
BEGIN 
SELECT top 1 gameName,releaseDate from Game INNER JOIN GamePlatform
on Game.platformID=GamePlatform.platformID where GamePlatform.platformID=1
Order by releaseDate desc
END
GO

-- %% [markdown]
-- # [dbo].[sp_OyunListesi]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_OyunListesi]    Script Date: 05/01/2022 22:36:30 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


CREATE PROCEDURE [dbo].[sp_OyunListesi]
AS 
BEGIN 
SELECT gameName,uFirstName,count(UserAccount.uAccountID)as a from Game INNER JOIN GameList
on Game.gameID=GameList.gameID INNER JOIN UserAccount on UserAccount.uAccountID = GameList.uAccountID 
WHERE UserAccount.uAccountID = GameList.uAccountID Group by uFirstName,gameName ORDER BY uFirstName
END
GO

-- %% [markdown]
-- # [dbo].[sp_Platform_OyunSayisi]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_Platform_OyunSayisi]    Script Date: 05/01/2022 22:36:30 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


CREATE PROCEDURE [dbo].[sp_Platform_OyunSayisi]
AS 
BEGIN 
SELECT count(*)as OyunSayisi,platformName   From Game INNER JOIN GamePlatform on Game.platformID=GamePlatform.platformID
GROUP BY platformName 
ORDER BY COUNT(*) DESC 
END
GO

-- %% [markdown]
-- # [Gamerary]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [Gamerary] SET  READ_WRITE 
GO
